# %% [markdown]
# # Generate the Intron bed6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(100)
# %matplotlib inline

import pybedtools as pb
from tqdm import tqdm_notebook as tqdm

# %% [raw]
# !wget -P ref ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_29/gencode.v29.annotation.gtf.gz

# %% [raw]
# !wget -P ref ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M20/gencode.vM20.annotation.gtf.gz

# %%
f_gtf = 'ref/gencode.v29.annotation.gtf.gz'
f_out = 'ref/gencode.v29.intron.bed'
# f_gtf = 'ref/gencode.vM20.annotation.gtf.gz'
# f_out = 'ref/gencode.vM20.intron.bed'
is_gencode = True

# %%
def get_gencode_gene(s_attr):
     return [x.split()[1].replace('"', '') 
             for x in s_attr.split('; ') if x.startswith('gene_name')][0]

# %%
df_gtf = pd.read_csv(f_gtf, header=None, sep='\t', comment='#')
df_gtf.columns = ['chr', 'source', 'feature', 'start', 'end', 'score', 
                  'strand', 'frame', 'attribute']
if is_gencode:
    df_gtf['symbol'] = df_gtf['attribute'].map(get_gencode_gene)
    
else:
    df_gtf['symbol'] = df_gtf.attribute.str.split('"').str.get(1)
df_gtf.head()
# Out:
#     chr  source     feature  start    end score strand frame  \
# 0  chr1  HAVANA        gene  11869  14409     .      +     .
# 1  chr1  HAVANA  transcript  11869  14409     .      +     .
# 2  chr1  HAVANA        exon  11869  12227     .      +     .
# 3  chr1  HAVANA        exon  12613  12721     .      +     .
# 4  chr1  HAVANA        exon  13221  14409     .      +     .
#
#                                            attribute   symbol
# 0  gene_id "ENSG00000223972.5"; gene_type "transc...  DDX11L1
# 1  gene_id "ENSG00000223972.5"; transcript_id "EN...  DDX11L1
# 2  gene_id "ENSG00000223972.5"; transcript_id "EN...  DDX11L1
# 3  gene_id "ENSG00000223972.5"; transcript_id "EN...  DDX11L1
# 4  gene_id "ENSG00000223972.5"; transcript_id "EN...  DDX11L1

# %%
# %%time

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

l_g_without_intron = []
flag_intron = 0
for i,syn in enumerate(df_gtf.symbol.unique()):
    df_q = df_gtf.query('symbol==@syn')

    c = df_q.chr.unique()[0]
    s = df_q.start.min()
    e = df_q.end.max()
    syn = df_q.symbol.unique()[0]
    sc = '.'
    st = df_q.strand.unique()[0]
    
    df_q = df_q[df_q.feature != 'transcript']
    df_q = df_q[df_q.feature != 'gene'] 
    
    d = pd.DataFrame([[c,s,e,syn,sc,st]])
    g = pb.BedTool.from_dataframe(d)

    try:
        df_int_q = g.subtract(pb.BedTool.from_dataframe(df_q)).to_dataframe()
    except:
#         print(syn) # print genes without any intron.
        l_g_without_intron.append(syn)
    
    if flag_intron == 0:
        df_intron = df_int_q
        flag_intron = 1

    elif df_int_q.name[0] == syn:
        df_intron = pd.concat([df_intron, df_int_q])

df_intron.to_csv(f_out, index=None, sep='\t', header=None)
# Out:
# CPU times: user 2h 14min 15s, sys: 1h 15min 31s, total: 3h 29min 46s
# Wall time: 4h 3min 54s

# %%
print(l_g_without_intron)
# Out:
 'AL590556.1', 'RN7SL386P', 'RNU6-1022P', 'RN7SL186P', 'RNU6-776P', 'AL031281.4', 'AL031281.1', 'MIR4418', 'PPIAP34', 'AL591122.1', 'MIR6127', 'MIR4684', 'MIR4253', 'MIR3115', 'MIR4419A', 'AL161672.1', 'RNU6-514P', 'RNU6-135P', 'HTR1D', 'AL109936.1', 'LINC01355', 'AL109936.2', 'BTBD6P1', 'MIR378F', 'AL590609.2', 'AL445686.1', 'RNU6-1208P', 'MIR6731', 'AL445471.2', 'MIR4425', 'AL121994.1', 'AL031432.4', 'AL031432.5', 'AL031432.3', 'SDHDP6', 'AL031284.1', 'AL020996.3', 'SNRPFP2', 'AL033528.1', 'MIR3917', 'RNU6-110P', 'AL355877.2', 'AL451139.1', 'AL513365.1', 'DPPA2P2', 'MIR1976', 'RN7SL679P', 'RNU7-29P', 'AL627313.1', 'AL627082.1', 'AL512408.1', 'RN7SL165P', 'SFN', 'AL356390.1', 'OSTCP2', 'AL590640.2', 'CHCHD3P3', 'NPM1P39', 'SNRPEP7', 'RNU6-48P', 'ACTG1P20', 'AL031729.1', 'RNU6-949P', 'CHMP1AP1', 'RNU6-424P', 'AL020997.1', 'RPEP3', 'AL020997.2', 'AL020997.3', 'RNU6-1245P', 'SCARNA1', 'AL512288.2', 'RN7SL559P', 'SPCS2P4', 'RNU6-176P', 'AL353622.1', 'AL353622.2', 'CR391992.1', 'RNU6ATAC27P', 'SNORA73A', 'SNORA73B', 'AL513497.1', 'SNORD99', 'SNORA61', 'SNORA44', 'SNORA16A', 'AL360012.1', 'RNU11', 'AL138785.1', 'AL645944.1', 'AL021921.1', 'MIR4420', 'RN7SKP91', 'RN7SL371P', 'AL356320.2', 'AL356320.1', 'AC114495.1', 'AC114495.2', 'AC209007.1', 'RNU6-40P', 'MIR4254', 'MIR5585', 'GAPDHP20', 'AL356986.1', 'RN7SL122P', 'AL031602.1', 'AL355864.1', 'AL662907.1', 'AL662907.2', 'AL513327.3', 'MIR3605', 'RN7SKP16', 'TLR12P', 'AC115285.1', 'HSPD1P14', 'RNA5SP42', 'AC115286.1', 'MIR552', 'EFCAB14P1', 'RN7SL503P', 'RPL5P4', 'AL139286.1', 'AL139286.2', 'RN7SL131P', 'UBE2V2P4', 'RNU4-27P', 'SNORA63C', 'FTLP18', 'MIR4255', 'RNU6-636P', 'RNA5SP43', 'RPS29P6', 'MIR6732', 'MIR5581', 'FTH1P1', 'AL034379.1', 'AL929472.1', 'AL929472.4', 'RNU6-584P', 'RN ...

# %%
df_intron.head(10)
# Out:
#   chrom  start    end     name score strand
# 0  chr1  12227  12612  DDX11L1     .      +
# 1  chr1  12721  12974  DDX11L1     .      +
# 2  chr1  13052  13220  DDX11L1     .      +
# 0  chr1  14501  15004   WASH7P     .      -
# 1  chr1  15038  15795   WASH7P     .      -
# 2  chr1  15947  16606   WASH7P     .      -
# 3  chr1  16765  16857   WASH7P     .      -
# 4  chr1  17055  17232   WASH7P     .      -
# 5  chr1  17368  17605   WASH7P     .      -
# 6  chr1  17742  17914   WASH7P     .      -
