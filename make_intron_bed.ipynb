# %% [markdown]
# # Generate the Intron bed6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(100)
# %matplotlib inline

import pybedtools as pb
from tqdm import tqdm_notebook as tqdm

# %% [raw]
# !wget -P ref ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_29/gencode.v29.annotation.gtf.gz

# %% [raw]
# !wget -P ref ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M20/gencode.vM20.annotation.gtf.gz

# %%
# f_gtf = 'ref/gencode.v29.annotation.gtf.gz'
# f_out = 'ref/gencode.v29.intron.bed.gz'
f_gtf = 'ref/gencode.vM20.annotation.gtf.gz'
f_out = 'ref/gencode.vM20.intron.bed.gz'
is_gencode = True

# %%
def get_gencode_gene(s_attr):
     return [x.split()[1].replace('"', '') 
             for x in s_attr.split('; ') if x.startswith('gene_name')][0]

# %%
df_gtf = pd.read_csv(f_gtf, header=None, sep='\t', comment='#')
df_gtf.columns = ['chr', 'source', 'feature', 'start', 'end', 'score', 
                  'strand', 'frame', 'attribute']
if is_gencode:
    df_gtf['symbol'] = df_gtf['attribute'].map(get_gencode_gene)
    
else:
    df_gtf['symbol'] = df_gtf.attribute.str.split('"').str.get(1)
df_gtf.head()
# Out:
#     chr   source     feature    start      end score strand frame  \
# 0  chr1   HAVANA        gene  3073253  3074322     .      +     .
# 1  chr1   HAVANA  transcript  3073253  3074322     .      +     .
# 2  chr1   HAVANA        exon  3073253  3074322     .      +     .
# 3  chr1  ENSEMBL        gene  3102016  3102125     .      +     .
# 4  chr1  ENSEMBL  transcript  3102016  3102125     .      +     .
#
#                                            attribute         symbol
# 0  gene_id "ENSMUSG00000102693.1"; gene_type "TEC...  4933401J01Rik
# 1  gene_id "ENSMUSG00000102693.1"; transcript_id ...  4933401J01Rik
# 2  gene_id "ENSMUSG00000102693.1"; transcript_id ...  4933401J01Rik
# 3  gene_id "ENSMUSG00000064842.1"; gene_type "snR...        Gm26206
# 4  gene_id "ENSMUSG00000064842.1"; transcript_id ...        Gm26206

# %%
# %%time

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

l_g_without_intron = []
flag_intron = 0
for i,syn in enumerate(df_gtf.symbol.unique()):
    df_q = df_gtf.query('symbol==@syn')

    c = df_q.chr.unique()[0]
    s = df_q.start.min()
    e = df_q.end.max()
    syn = df_q.symbol.unique()[0]
    sc = '.'
    st = df_q.strand.unique()[0]
    
    df_q = df_q[df_q.feature != 'transcript']
    df_q = df_q[df_q.feature != 'gene'] 
    
    d = pd.DataFrame([[c,s,e,syn,sc,st]])
    g = pb.BedTool.from_dataframe(d)

    try:
        df_int_q = g.subtract(pb.BedTool.from_dataframe(df_q)).to_dataframe()
    except:
#         print(syn) # print genes without any intron.
        l_g_without_intron.append(syn)
    
    if 'df_int_q' in locals():
        if flag_intron == 0:
            df_intron = df_int_q
            flag_intron = 1

        elif df_int_q.name[0] == syn:
            df_intron = pd.concat([df_intron, df_int_q])

df_intron.to_csv(f_out, index=None, sep='\t', header=None)
# Out:
# CPU times: user 1h 23min 9s, sys: 44min 36s, total: 2h 7min 45s
# Wall time: 2h 26min 50s

# %%
print(l_g_without_intron)
# Out:
# ['4933401J01Rik', 'Gm26206', 'Gm18956', 'Gm37180', 'Gm37363', 'Gm37686', 'Gm37329', 'Gm7341', 'Gm38148', 'Gm10568', 'Gm38385', 'Gm27396', 'Gm37483', 'Gm22307', 'Gm38076', 'Gm7369', 'Gm6085', 'Gm6119', 'Gm25493', 'Gm2053', 'Gm6123', 'Gm37144', 'Gm6104', 'Gm37277', 'Gm17100', 'Gm37079', 'Gm17101', 'Gm37567', 'Gm38264', 'Gm36965', 'Gm22463', 'Gm37429', 'Npbwr1', 'Gm19214', '4732440D04Rik', 'Gm2147', 'Gm7417', 'Gm42492', 'Gm7449', 'Gm37275', 'Gm37225', 'Gm37489', 'Gm26983', 'Gm38372', 'Gm9826', 'Nras-ps2', 'Gm23274', 'Gm19002', 'Gm37791', 'Gm7470', 'Rps2-ps2', 'Gm38024', 'Gm16284', 'Gm38259', 'Gm23358', 'Gm37005', 'Gm15452', 'Gm36964', 'Gm24276', 'Gm6152', 'Gm7445', 'Gm7493', 'Gm37629', 'Gm38008', 'Gm37143', 'Gm18299', 'Gm7512', 'Gm24765', 'Rrs1', 'Gm6161', 'Gm6195', 'Gm22607', 'Snord87', 'E330040D14Rik', 'Gm24674', '1700047N06Rik', 'Gm26348', 'Gm37569', 'Gm38005', 'Gm15604', 'Gm25253', 'Gm15603', 'Gm37133', 'Gm5522', 'Gm28659', 'Gm22963', 'Gm24173', 'Gm28686', 'Gm37410', 'Gm38178', 'Gm29273', 'Gm38069', 'Gm7560', 'Gm22633', 'Mir6341', 'Gm2383', 'Gm6216', 'Gm29663', 'Gm37162', 'Gm5250', 'Gm38376', 'Gm37409', 'Gm27881', 'Gm38223', 'Gm37702', 'Gm23169', 'Gm38120', 'Gm38380', 'Gm7593', 'Gm38319', 'Gm26273', 'Gm5523', 'Gm36947', 'Gm25491', 'Gm37400', 'Gm22616', 'Gm37444', 'Gm37412', 'Smt3h2-ps4', 'Rpl5-ps1', 'Gm26345', 'Gm10566', 'Gm38116', 'Gm37138', 'Gm25227', 'Gm25168', 'Gm28669', 'Gm37509', 'Gm23259', 'Gm7634', 'Gm38249', 'Gm38342', 'Gm7654', 'Gm29649', 'Gm5828', '4921511E07Rik', 'Gm28785', 'Gm5251', 'Rbm6-ps1', 'Gm6075', 'Gm25166', 'Gm7690', 'Gm17837', 'Gm5252', 'Gm24075', 'Gm28343', 'Gm28344', 'Gm10075', 'Gm28341', 'Gm4849', 'Gm24633', 'Gm38382', 'Gm37315', 'Gm15795', 'Gm24162', 'Mir206', 'Mir133b', 'Gm20587', 'Gm24723', 'Gm24171', 'Gm38224', 'Gm16327', 'Gm16533', 'Gm16328', 'Gm36949', 'Gm7658', 'Gm38243', 'Gm5696', 'Gm28239', 'Gm26866', '4933415F23Rik', 'Gm24176', 'Gm6420', 'Mir30a', 'Gm27028', 'Mir30c-2', 'Gm29107', 'Gm20954', 'Gm7784', 'Gm26524', 'Gm37580', 'Gm26607', 'Gm26418', 'Tubb4b-ps2', 'Gm28439', 'Gm10222', 'Gm28438', 'Gm28437', 'Gm10925', 'Gm28661', 'Gm29216', 'Gm9443', 'Gm15702', 'Gm20172', 'Gm22260', 'Gm37543', 'Gm37331', 'Gm37211', 'Gm37862', 'Gm38286', 'Gm37880', 'Gm25294', 'Gm37011', 'Gm29214', 'Gm37051', 'Gm38260', 'Gm37628', '8030445P17Rik', 'Gm38198', 'Gm37077', 'Gm37895', 'Gm36952', 'Gm37602', '2900022M07Rik', '2900002M20Rik', 'Gm9884', 'Gm18443', 'Gm19123', 'Gm24064', 'n-R5s209', 'Gm19641', 'Gm18776', 'Gm19028', 'Gm38089', 'Gm7846', 'Gm5697', 'Gm6462', 'Gm18033', 'Gm25586', 'Gm22679', 'Gm23785', 'Mir6342', 'Gm5525', 'Gm7858', 'Gm23771', 'Gm27430', 'Gm2914', 'Gm37522', 'Gm37906', 'AC153137.1', 'Gm9458', 'Gm27362', 'Gm7893', 'Pih1d3', 'Gm26145', 'Gm4850', 'Gm28645', 'Gm6489', 'Gm19680', 'Gm23032', 'Gm7910', 'Gm25814', 'Gm37999', 'Gm37110', 'Gm37911', 'Gm9839', 'Gm37792', 'Gm5415', 'Gm24732', 'Gm37426', 'Gm23024', 'Gm37151', 'Gm28624', 'Gm37724', 'Gm7114', 'Gm4785', 'Gm24901', 'Gm2987', 'Gm25792', 'Gm18799', 'Gm7933', 'Gm23453', 'Gm29228', 'Gm37618', 'Gm17813', '1700001G17Rik', 'Gm38173', 'Gm37905', 'Gm15455', 'Gm37067', 'Gm37354', 'Gm28631', 'Gm23792', 'Gm38157', 'Mir6896', 'A930005N03Rik', 'Gm37385', 'Gm3052', 'Gm37233', 'Mir5103', 'Gm28416', 'Gm28419', '1700101I19Rik', 'Gm28418', 'Gm36984', 'Gm29730', 'AA619741', 'Gm37224', 'Gm37845', 'Gm38336', 'Gm37127', 'Gm19430', 'Gm37670', 'Gm8009', 'Gm38027', 'Gm25096', 'Gm25634', 'Gm8022', 'Gm38049', 'Mir6897', '4930403P22Rik', 'Mir6898', 'Gm37909', 'Gm47280', 'Gm6428', 'Gm24133', 'Gm18828', 'Gm37506', 'F830112A20Rik', 'Rpl12-ps1', 'n-R5s210', 'Gm37020', '1700074A21Rik', 'Gm37135', '4930594C11Rik', 'Gm43213', '4930470B04Rik', 'Gm19863', 'Gm23409', 'Gm34727', 'Gm38135', '2610300A13Rik', 'Gm6621', 'Gm37309', 'Gm37091', 'Mir6349', 'Gm20428', 'Gm3617', 'Gm37265', 'Gm24826', 'Snord89', 'Gm23722', 'Gm5100', '4930456G14Rik', 'Gm37347', 'Gm38070', 'Gm17970', 'Gm37435', 'Gm5973', 'Gm28634', 'Gm5267', 'Gm8176', 'Gm9915', 'Gm29664', '4930420N18Rik', 'Pou3f3', 'Dalir', 'Gm23126', ...
